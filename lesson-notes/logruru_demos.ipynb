# %% [markdown]
# # Loguru Make Logging Simple
#
# - No Handler,no Formatter,No Filter: One Function rules all
# - Easier file logging with rotation/rention/compression
# - Exceptions catching within threads or main
# - Pretty logging with colors
# - Asynchonous,thread-safe,multiprocess-safe
# - .........
#
# * [github](https://github.com/Delgan/loguru#ready-to-use-out-of-the-box-without-boilerplate)

# %% [markdown]
# ## Ready to Use out of box without boilerplate

# %%
from loguru import logger
logger.debug("that's it, it is ready")
logger.info("that's it, it is ready")
# Out:
# 2020-03-29 22:32:59.270 | DEBUG    | __main__:<module>:2 - that's it, it is ready
# 2020-03-29 22:32:59.273 | INFO     | __main__:<module>:3 - that's it, it is ready

# %% [markdown]
# ## No Handler,no Formatter,No Filter: One Function rules all

# %%
import sys
logger.add(sys.stderr, format="{time} {level} {message}", filter="my_module", level="INFO")
logger.add("file_{time}.log",rotation="200 MB")
logger.add("file_{time}.log",rotation="12:00")
logger.add("file_{time}.log",rotation="1 week",compression="zip")
logger.add(sys.stdout, colorize=True, format="<green>{time}</green> <level>{message}</level>")
# Out:
# 10

# %%
logger.info("If you're using Python {}, prefer {feature} of course!", 3.6, feature="f-strings")
# Out:
# 2020-03-29 22:36:42.288 | INFO     | __main__:<module>:1 - If you're using Python 3.6, prefer f-strings of course!

# %% [markdown]
# ## Exceptions catching within threads or main

# %%
@logger.catch
def my_function(x, y, z):
    # An error? It's caught anyway!
    return 1 / (x + y + z)

def func(a, b):
    return a / b

def nested(c):
    try:
        func(5, c)
    except ZeroDivisionError:
        logger.exception("What?!")

nested(0)
my_function(1,2,3)
nested(0)
# Out:
# 2020-03-29 22:39:53.527 | ERROR    | __main__:nested:13 - What?!
# Traceback (most recent call last):
#   File "/home/patrick/anaconda3/lib/python3.8/runpy.py", line 193, in _run_module_as_main
#     return _run_code(code, main_globals, None,
#            │         │     └ {'__name__': '__main__', '__doc__': 'Entry point for launching an IPython kernel.\n\nThis is separate from the ipykernel pack...
#            │         └ <code object <module> at 0x7f94d9d40030, file "/home/patrick/anaconda3/lib/python3.8/site-packages/ipykernel_launcher.py", li...
#            └ <function _run_code at 0x7f94d9cba3a0>
#   File "/home/patrick/anaconda3/lib/python3.8/runpy.py", line 86, in _run_code
#     exec(code, run_globals)
#          │     └ {'__name__': '__main__', '__doc__': 'Entry point for launching an IPython kernel.\n\nThis is separate from the ipykernel pack...
#          └ <code object <module> at 0x7f94d9d40030, file "/home/patrick/anaconda3/lib/python3.8/site-packages/ipykernel_launcher.py", li...
#   File "/home/patrick/anaconda3/lib/python3.8/site-packages/ipykernel_launcher.py", line 16, in <module>
#     app.launch_new_instance()
#     │   └ <bound method Application.launch_instance of <class 'ipykernel.kernelapp.IPKernelApp'>>
#     └ <module 'ipykernel.kernelapp' from '/home/patrick/anaconda3/lib/python3.8/site-packages/ipykernel/kernelapp.py'>
#   File "/home/patrick/anaconda3/lib/python3.8/site-packages/traitlets/config/application.py", line 664, in launch_instance
#     app.start()
#     │   └ <function IPKernelApp.start at 0x7f94d45caaf0>
#     └ <ipykernel.kernelapp.IPKernelApp object at 0x7f94d9d6c7f0>
#   File "/home/patrick/anaconda3/lib/python3.8/site-packages/ipykernel/kernelapp.py", line 583, in start
#     self.io_loop.start()
#     │    │       └ <function BaseAsyncIOLoop.start at 0x7f94d4714a60>
#     │    └ <tornado.platform.asyncio.AsyncIOMainLoop object at 0x7f94d45df2b0>
#     └ <ipykernel.kernelapp.IPKernelApp object at 0x7f94d9d6c7f0>
#   File "/home/patrick/anaconda3/lib/python3.8/site-packages/tornado/platform/asyncio.py", line 149, in start
#     self.asyncio_loop.run_forever()
#     │    │            └ <function BaseEventLoop.run_forever at 0x7f94d71ece50>
#     │    └ <_UnixSelectorEventLoop running=True closed=False debug=False>
#     └ <tornado.platform.asyncio.AsyncIOMainLoop object at 0x7f94d45df2b0>
#   File "/home/patrick/anaconda3/lib/python3.8/asyncio/base_events.py", line 567, in run_forever
#     self._run_once()
#     │    └ <function BaseEventLoop._run_once at 0x7f94d71ef9d0>
#     └ <_UnixSelectorEventLoop running=True closed=False debug=False>
#   File "/home/patrick/anaconda3/lib/python3.8/asyncio/base_events.py", line 1855, in _run_once
#     handle._run()
#     │      └ <function Handle._run at 0x7f94d72344c0>
#     └ <Handle IOLoop.add_future.<locals>.<lambda>(<Future finis...2300>, ...]))>) at /home/patrick/anaconda3/lib/python3.8/site-pac...
#   File "/home/patrick/anaconda3/lib/python3.8/asyncio/events.py", line 81, in _run
#     self._context.run(self._callback, *self._args)
#     │    │            │    │           │    └ <member '_args' of 'Handle' objects>
#     │    │            │    │           └ <Handle IOLoop.add_future.<locals>.<lambda>(<Future finis...2300>, ...]))>) at /home/patrick/anaconda3/lib/python3.8/site-pac...
#     │    │            │    └ <member '_callback' of 'Handle' objects>
#     │    │            └ <Handle IOLoop.add_future.<locals>.<lambda>(<Future finis...2300>, ...]))>) at /home/patrick/anaconda3/lib/python3.8/site-pac...
#     │    └ <member '_context' of 'Handle' objects>
#     └ <Handle IOLoop.add_future.<locals>.<lambda>(<Future finis...2300>, ...]))>) at /home/patrick/anaconda3/lib/python3.8/site-pac...
#   File "/home/patrick/anaconda3/lib/python3.8/site-packages/tornado/ioloop.py", line 690, in <lambda>
#     lambda f: self._run_callback(functools.partial(callback, future))
#            │  │    │             │         │       │         └ <Future finished result=(10, 12, <bound method...7f94d45dfdc0>>, (<zmq.eventloo...x7f94d45df580>, [<zmq.sugar.fr...x7f94d1562...
#            │  │    │             │         │       └ <function Runner.handle_yield.<locals>.inner at 0x7f94d03bbc10>
#            │  │    │             │         └ <class 'functools.partial'>
#            │  │    │             └ <module 'functools' from '/home/patrick/anaconda3/lib/python3.8/functools.py'>
#            │  │    └ <function IOLoop._run_callback at 0x7f94d481a820>
#            │  └ <tornado.platform.asyncio.AsyncIOMainLoop object at 0x7f94d45df2b0>
#            └ <Future finished result=(10, 12, <bound method...7f94d45dfdc0>>, (<zmq.eventloo...x7f94d45df580>, [<zmq.sugar.fr...x7f94d1562...
#   File "/home/patrick/anaconda3/lib/python3.8/site-packages/tornado/ioloop.py", line 743, in _run_callback
#     ret = callback()
#           └ functools.partial(<function Runner.handle_yield.<locals>.inner at 0x7f94d03bbc10>, <Future finished result=(10, 12, <bound me...
#   File "/home/patrick/anaconda3/lib/python3.8/site-packages/tornado/gen.py", line 787, in inner
#     self.run()
#     │    └ <function Runner.run at 0x7f94d4714310>
#     └ <tornado.gen.Runner object at 0x7f94d1549eb0>
#   File "/home/patrick/anaconda3/lib/python3.8/site-packages/tornado/gen.py", line 748, in run
#     yielded = self.gen.send(value)
#               │    │   │    └ (10, 12, <bound method Kernel.dispatch_shell of <ipykernel.ipkernel.IPythonKernel object at 0x7f94d45dfdc0>>, (<zmq.eventloop...
#               │    │   └ <method 'send' of 'generator' objects>
#               │    └ <generator object Kernel.process_one at 0x7f94d763c3c0>
#               └ <tornado.gen.Runner object at 0x7f94d1549eb0>
#   File "/home/patrick/anaconda3/lib/python3.8/site-packages/ipykernel/kernelbase.py", line 361, in process_one
#     yield gen.maybe_future(dispatch(*args))
#           │   │            │         └ (<zmq.eventloop.zmqstream.ZMQStream object at 0x7f94d45df580>, [<zmq.sugar.frame.Frame object at 0x7f94d15629e0>, <zmq.sugar....
#           │   │            └ <bound method Kernel.dispatch_shell of <ipykernel.ipkernel.IPythonKernel object at 0x7f94d45dfdc0>>
#           │   └ <function maybe_future at 0x7f94d4705ee0>
#           └ <module 'tornado.gen' from '/home/patrick/anaconda3/lib/python3.8/site-packages/tornado/gen.py'>
#   File "/home/patrick/anaconda3/lib/python3.8/site-packages/tornado/gen.py", line 209, in wrapper
#     yielded = next(result)
#                    └ <generator object Kernel.dispatch_shell at 0x7f94d03f6cf0>
#   File "/home/patrick/anaconda3/lib/python3.8/site-packages/ipykernel/kernelbase.py", line 268, in dispatch_shell
#     yield gen.maybe_future(handler(stream, idents, msg))
#           │   │            │       │       │       └ {'header': {'msg_id': 'd3a320bd0f53435b8eda4c2293526724', 'username': 'username', 'session': '481b4fc0ab10447f9d558f12496fe7c...
#           │   │            │       │       └ [b'481b4fc0ab10447f9d558f12496fe7cc']
#           │   │            │       └ <zmq.eventloop.zmqstream.ZMQStream object at 0x7f94d45df580>
#           │   │            └ <bound method Kernel.execute_request of <ipykernel.ipkernel.IPythonKernel object at 0x7f94d45dfdc0>>
#           │   └ <function maybe_future at 0x7f94d4705ee0>
#           └ <module 'tornado.gen' from '/home/patrick/anaconda3/lib/python3.8/site-packages/tornado/gen.py'>
#   File "/home/patrick/anaconda3/lib/python3.8/site-packages/tornado/gen.py", line 209, in wrapper
#     yielded = next(result)
#                    └ <generator object Kernel.execute_request at 0x7f94d03acf90>
#   File "/home/patrick/anaconda3/lib/python3.8/site-packages/ipykernel/kernelbase.py", line 539, in execute_request
#     self.do_execute(
#     │    └ <function IPythonKernel.do_execute at 0x7f94d45c5430>
#     └ <ipykernel.ipkernel.IPythonKernel object at 0x7f94d45dfdc0>
#   File "/home/patrick/anaconda3/lib/python3.8/site-packages/tornado/gen.py", line 209, in wrapper
#     yielded = next(result)
#                    └ <generator object IPythonKernel.do_execute at 0x7f94d03c7120>
#   File "/home/patrick/anaconda3/lib/python3.8/site-packages/ipykernel/ipkernel.py", line 300, in do_execute
#     res = shell.run_cell(code, store_history=store_history, silent=silent)
#           │     │        │                   │                     └ False
#           │     │        │                   └ True
#           │     │        └ '@logger.catch\ndef my_function(x, y, z):\n    # An error? It\'s caught anyway!\n    return 1 / (x + y + z)\n\ndef func(a, b)...
#           │     └ <function ZMQInteractiveShell.run_cell at 0x7f94d45b6b80>
#           └ <ipykernel.zmqshell.ZMQInteractiveShell object at 0x7f94d45dfd60>
#   File "/home/patrick/anaconda3/lib/python3.8/site-packages/ipykernel/zmqshell.py", line 536, in run_cell
#     return super(ZMQInteractiveShell, self).run_cell(*args, **kwargs)
#                  │                    │               │       └ {'store_history': True, 'silent': False}
#                  │                    │               └ ('@logger.catch\ndef my_function(x, y, z):\n    # An error? It\'s caught anyway!\n    return 1 / (x + y + z)\n\ndef func(a, b...
#                  │                    └ <ipykernel.zmqshell.ZMQInteractiveShell object at 0x7f94d45dfd60>
#                  └ <class 'ipykernel.zmqshell.ZMQInteractiveShell'>
#   File "/home/patrick/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py", line 2857, in run_cell
#     result = self._run_cell(
#              │    └ <function InteractiveShell._run_cell at 0x7f94d73cf4c0>
#              └ <ipykernel.zmqshell.ZMQInteractiveShell object at 0x7f94d45dfd60>
#   File "/home/patrick/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py", line 2886, in _run_cell
#     return runner(coro)
#            │      └ <coroutine object InteractiveShell.run_cell_async at 0x7f94d15489c0>
#            └ <function _pseudo_sync_runner at 0x7f94d73bbb80>
#   File "/home/patrick/anaconda3/lib/python3.8/site-packages/IPython/core/async_helpers.py", line 68, in _pseudo_sync_runner
#     coro.send(None)
#     │    └ <method 'send' of 'coroutine' objects>
#     └ <coroutine object InteractiveShell.run_cell_async at 0x7f94d15489c0>
#   File "/home/patrick/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py", line 3062, in run_cell_async
#     has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#                        │    │             │        │     └ '<ipython-input-9-fef5f0ab64be>'
#                        │    │             │        └ [<_ast.FunctionDef object at 0x7f94d046f6a0>, <_ast.FunctionDef object at 0x7f94d046f3a0>, <_ast.FunctionDef object at 0x7f94...
#                        │    │             └ <_ast.Module object at 0x7f94d046fb50>
#                        │    └ <function InteractiveShell.run_ast_nodes at 0x7f94d73cf790>
#                        └ <ipykernel.zmqshell.ZMQInteractiveShell object at 0x7f94d45dfd60>
#   File "/home/patrick/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py", line 3254, in run_ast_nodes
#     if (await self.run_code(code, result,  async_=asy)):
#               │    │        │     │               └ False
#               │    │        │     └ <ExecutionResult object at 7f94d03b2c40, execution_count=9 error_before_exec=None error_in_exec=None info=<ExecutionInfo obje...
#               │    │        └ <code object <module> at 0x7f94d03ce030, file "<ipython-input-9-fef5f0ab64be>", line 15>
#               │    └ <function InteractiveShell.run_code at 0x7f94d73cf8b0>
#               └ <ipykernel.zmqshell.ZMQInteractiveShell object at 0x7f94d45dfd60>
#   File "/home/patrick/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py", line 3331, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#          │         │    │               │    └ {'__name__': '__main__', '__doc__': 'Automatically created module for IPython interactive environment', '__package__': None, ...
#          │         │    │               └ <ipykernel.zmqshell.ZMQInteractiveShell object at 0x7f94d45dfd60>
#          │         │    └ <property object at 0x7f94d73c82c0>
#          │         └ <ipykernel.zmqshell.ZMQInteractiveShell object at 0x7f94d45dfd60>
#          └ <code object <module> at 0x7f94d03ce030, file "<ipython-input-9-fef5f0ab64be>", line 15>
#   File "<ipython-input-9-fef5f0ab64be>", line 15, in <module>
#     nested(0)
#     └ <function nested at 0x7f94d03bb9d0>
# > File "<ipython-input-9-fef5f0ab64be>", line 11, in nested
#     func(5, c)
#     │       └ 0
#     └ <function func at 0x7f94d03bb8b0>
#   File "<ipython-input-9-fef5f0ab64be>", line 7, in func
#     return a / b
#            │   └ 0
#            └ 5
#
# ZeroDivisionError: division by zero
# 2020-03-29T22:39:53.527069+0800 What?!
# Traceback (most recent call last):
#   File "/home/patrick/anaconda3/lib/python3.8/runpy.py", line 193, in _run_module_as_main
#     return _run_code(code, main_globals, None,
#            │         │     └ {'__name__': '__main__', '__doc__': 'Entry point for launching an IPython kernel.\n\nThis is separate from the ipykernel pack...
#            │         └ <code object <module> at 0x7f94d9d40030, file "/home/patrick/anaconda3/lib/python3.8/site-packages/ipykernel_launcher.py", li...
#            └ <function _run_code at 0x7f94d9cba3a0>
#   File "/home/patrick/anaconda3/lib/python3.8/runpy.py", line 86, in _run_code
#     exec(code, run_globals)
#          │     └ {'__name__': '__main__', '__doc__': 'Entry point for launching an IPython kernel.\n\nThis is separate from the ipykernel pack...
#          └ <code object <module> at 0x7f94d9d40030, file "/home/patrick/anaconda3/lib/python3.8/site-packages/ipykernel_launcher.py", li...
#   File "/home/patrick/anaconda3/lib/python3.8/site-packages/ipykernel_launcher.py", line 16, in <module>
#     app.launch_new_instance()
#     │   └ <bound method Application.launch_instance of <class 'ipykernel.kernelapp.IPKernelApp'>>
#     └ <module 'ipykernel.kernelapp' from '/home/patrick/anaconda3/lib/python3.8/site-packages/ipykernel/kernelapp.py'>
#   File "/home/patrick/anaconda3/lib/python3.8/site-packages/traitlets/config/application.py", line 664, in launch_instance
#     app.start()
#     │   └ <function IPKernelApp.start at 0x7f94d45caaf0>
#     └ <ipykernel.kernelapp.IPKernelApp object at 0x7f94d9d6c7f0>
#   File "/home/patrick/anaconda3/lib/python3.8/site-packages/ipykernel/kernelapp.py", line 583, in start
#     self.io_loop.start()
#     │    │       └ <function BaseAsyncIOLoop.start at 0x7f94d4714a60>
#     │    └ <tornado.platform.asyncio.AsyncIOMainLoop object at 0x7f94d45df2b0>
#     └ <ipykernel.kernelapp.IPKernelApp object at 0x7f94d9d6c7f0>
#   File "/home/patrick/anaconda3/lib/python3.8/site-packages/tornado/platform/asyncio.py", line 149, in start
#     self.asyncio_loop.run_forever()
#     │    │            └ <function BaseEventLoop.run_forever at 0x7f94d71ece50>
#     │    └ <_UnixSelectorEventLoop running=True closed=False debug=False>
#     └ <tornado.platform.asyncio.AsyncIOMainLoop object at 0x7f94d45df2b0>
#   File "/home/patrick/anaconda3/lib/python3.8/asyncio/base_events.py", line 567, in run_forever
#     self._run_once()
#     │    └ <function BaseEventLoop._run_once at 0x7f94d71ef9d0>
#     └ <_UnixSelectorEventLoop running=True closed=False debug=False>
#   File "/home/patrick/anaconda3/lib/python3.8/asyncio/base_events.py", line 1855, in _run_once
#     handle._run()
#     │      └ <function Handle._run at 0x7f94d72344c0>
#     └ <Handle IOLoop.add_future.<locals>.<lambda>(<Future finis...2300>, ...]))>) at /home/patrick/anaconda3/lib/python3.8/site-pac...
#   File "/home/patrick/anaconda3/lib/python3.8/asyncio/events.py", line 81, in _run
#     self._context.run(self._callback, *self._args)
#     │    │            │    │           │    └ <member '_args' of 'Handle' objects>
#     │    │            │    │           └ <Handle IOLoop.add_future.<locals>.<lambda>(<Future finis...2300>, ...]))>) at /home/patrick/anaconda3/lib/python3.8/site-pac...
#     │    │            │    └ <member '_callback' of 'Handle' objects>
#     │    │            └ <Handle IOLoop.add_future.<locals>.<lambda>(<Future finis...2300>, ...]))>) at /home/patrick/anaconda3/lib/python3.8/site-pac...
#     │    └ <member '_context' of 'Handle' objects>
#     └ <Handle IOLoop.add_future.<locals>.<lambda>(<Future finis...2300>, ...]))>) at /home/patrick/anaconda3/lib/python3.8/site-pac...
#   File "/home/patrick/anaconda3/lib/python3.8/site-packages/tornado/ioloop.py", line 690, in <lambda>
#     lambda f: self._run_callback(functools.partial(callback, future))
#            │  │    │             │         │       │         └ <Future finished result=(10, 12, <bound method...7f94d45dfdc0>>, (<zmq.eventloo...x7f94d45df580>, [<zmq.sugar.fr...x7f94d1562...
#            │  │    │             │         │       └ <function Runner.handle_yield.<locals>.inner at 0x7f94d03bbc10>
#            │  │    │             │         └ <class 'functools.partial'>
#            │  │    │             └ <module 'functools' from '/home/patrick/anaconda3/lib/python3.8/functools.py'>
#            │  │    └ <function IOLoop._run_callback at 0x7f94d481a820>
#            │  └ <tornado.platform.asyncio.AsyncIOMainLoop object at 0x7f94d45df2b0>
#            └ <Future finished result=(10, 12, <bound method...7f94d45dfdc0>>, (<zmq.eventloo...x7f94d45df580>, [<zmq.sugar.fr...x7f94d1562...
#   File "/home/patrick/anaconda3/lib/python3.8/site-packages/tornado/ioloop.py", line 743, in _run_callback
#     ret = callback()
#           └ functools.partial(<function Runner.handle_yield.<locals>.inner at 0x7f94d03bbc10>, <Future finished result=(10, 12, <bound me...
#   File "/home/patrick/anaconda3/lib/python3.8/site-packages/tornado/gen.py", line 787, in inner
#     self.run()
#     │    └ <function Runner.run at 0x7f94d4714310>
#     └ <tornado.gen.Runner object at 0x7f94d1549eb0>
#   File "/home/patrick/anaconda3/lib/python3.8/site-packages/tornado/gen.py", line 748, in run
#     yielded = self.gen.send(value)
#               │    │   │    └ (10, 12, <bound method Kernel.dispatch_shell of <ipykernel.ipkernel.IPythonKernel object at 0x7f94d45dfdc0>>, (<zmq.eventloop...
#               │    │   └ <method 'send' of 'generator' objects>
#               │    └ <generator object Kernel.process_one at 0x7f94d763c3c0>
#               └ <tornado.gen.Runner object at 0x7f94d1549eb0>
#   File "/home/patrick/anaconda3/lib/python3.8/site-packages/ipykernel/kernelbase.py", line 361, in process_one
#     yield gen.maybe_future(dispatch(*args))
#           │   │            │         └ (<zmq.eventloop.zmqstream.ZMQStream object at 0x7f94d45df580>, [<zmq.sugar.frame.Frame object at 0x7f94d15629e0>, <zmq.sugar....
#           │   │            └ <bound method Kernel.dispatch_shell of <ipykernel.ipkernel.IPythonKernel object at 0x7f94d45dfdc0>>
#           │   └ <function maybe_future at 0x7f94d4705ee0>
#           └ <module 'tornado.gen' from '/home/patrick/anaconda3/lib/python3.8/site-packages/tornado/gen.py'>
#   File "/home/patrick/anaconda3/lib/python3.8/site-packages/tornado/gen.py", line 209, in wrapper
#     yielded = next(result)
#                    └ <generator object Kernel.dispatch_shell at 0x7f94d03f6cf0>
#   File "/home/patrick/anaconda3/lib/python3.8/site-packages/ipykernel/kernelbase.py", line 268, in dispatch_shell
#     yield gen.maybe_future(handler(stream, idents, msg))
#           │   │            │       │       │       └ {'header': {'msg_id': 'd3a320bd0f53435b8eda4c2293526724', 'username': 'username', 'session': '481b4fc0ab10447f9d558f12496fe7c...
#           │   │            │       │       └ [b'481b4fc0ab10447f9d558f12496fe7cc']
#           │   │            │       └ <zmq.eventloop.zmqstream.ZMQStream object at 0x7f94d45df580>
#           │   │            └ <bound method Kernel.execute_request of <ipykernel.ipkernel.IPythonKernel object at 0x7f94d45dfdc0>>
#           │   └ <function maybe_future at 0x7f94d4705ee0>
#           └ <module 'tornado.gen' from '/home/patrick/anaconda3/lib/python3.8/site-packages/tornado/gen.py'>
#   File "/home/patrick/anaconda3/lib/python3.8/site-packages/tornado/gen.py", line 209, in wrapper
#     yielded = next(result)
#                    └ <generator object Kernel.execute_request at 0x7f94d03acf90>
#   File "/home/patrick/anaconda3/lib/python3.8/site-packages/ipykernel/kernelbase.py", line 539, in execute_request
#     self.do_execute(
#     │    └ <function IPythonKernel.do_execute at 0x7f94d45c5430>
#     └ <ipykernel.ipkernel.IPythonKernel object at 0x7f94d45dfdc0>
#   File "/home/patrick/anaconda3/lib/python3.8/site-packages/tornado/gen.py", line 209, in wrapper
#     yielded = next(result)
#                    └ <generator object IPythonKernel.do_execute at 0x7f94d03c7120>
#   File "/home/patrick/anaconda3/lib/python3.8/site-packages/ipykernel/ipkernel.py", line 300, in do_execute
#     res = shell.run_cell(code, store_history=store_history, silent=silent)
#           │     │        │                   │                     └ False
#           │     │        │                   └ True
#           │     │        └ '@logger.catch\ndef my_function(x, y, z):\n    # An error? It\'s caught anyway!\n    return 1 / (x + y + z)\n\ndef func(a, b)...
#           │     └ <function ZMQInteractiveShell.run_cell at 0x7f94d45b6b80>
#           └ <ipykernel.zmqshell.ZMQInteractiveShell object at 0x7f94d45dfd60>
#   File "/home/patrick/anaconda3/lib/python3.8/site-packages/ipykernel/zmqshell.py", line 536, in run_cell
#     return super(ZMQInteractiveShell, self).run_cell(*args, **kwargs)
#                  │                    │               │       └ {'store_history': True, 'silent': False}
#                  │                    │               └ ('@logger.catch\ndef my_function(x, y, z):\n    # An error? It\'s caught anyway!\n    return 1 / (x + y + z)\n\ndef func(a, b...
#                  │                    └ <ipykernel.zmqshell.ZMQInteractiveShell object at 0x7f94d45dfd60>
#                  └ <class 'ipykernel.zmqshell.ZMQInteractiveShell'>
#   File "/home/patrick/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py", line 2857, in run_cell
#     result = self._run_cell(
#              │    └ <function InteractiveShell._run_cell at 0x7f94d73cf4c0>
#              └ <ipykernel.zmqshell.ZMQInteractiveShell object at 0x7f94d45dfd60>
#   File "/home/patrick/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py", line 2886, in _run_cell
#     return runner(coro)
#            │      └ <coroutine object InteractiveShell.run_cell_async at 0x7f94d15489c0>
#            └ <function _pseudo_sync_runner at 0x7f94d73bbb80>
#   File "/home/patrick/anaconda3/lib/python3.8/site-packages/IPython/core/async_helpers.py", line 68, in _pseudo_sync_runner
#     coro.send(None)
#     │    └ <method 'send' of 'coroutine' objects>
#     └ <coroutine object InteractiveShell.run_cell_async at 0x7f94d15489c0>
#   File "/home/patrick/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py", line 3062, in run_cell_async
#     has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#                        │    │             │        │     └ '<ipython-input-9-fef5f0ab64be>'
#                        │    │             │        └ [<_ast.FunctionDef object at 0x7f94d046f6a0>, <_ast.FunctionDef object at 0x7f94d046f3a0>, <_ast.FunctionDef object at 0x7f94...
#                        │    │             └ <_ast.Module object at 0x7f94d046fb50>
#                        │    └ <function InteractiveShell.run_ast_nodes at 0x7f94d73cf790>
#                        └ <ipykernel.zmqshell.ZMQInteractiveShell object at 0x7f94d45dfd60>
#   File "/home/patrick/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py", line 3254, in run_ast_nodes
#     if (await self.run_code(code, result,  async_=asy)):
#               │    │        │     │               └ False
#               │    │        │     └ <ExecutionResult object at 7f94d03b2c40, execution_count=9 error_before_exec=None error_in_exec=None info=<ExecutionInfo obje...
#               │    │        └ <code object <module> at 0x7f94d03ce030, file "<ipython-input-9-fef5f0ab64be>", line 15>
#               │    └ <function InteractiveShell.run_code at 0x7f94d73cf8b0>
#               └ <ipykernel.zmqshell.ZMQInteractiveShell object at 0x7f94d45dfd60>
#   File "/home/patrick/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py", line 3331, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#          │         │    │               │    └ {'__name__': '__main__', '__doc__': 'Automatically created module for IPython interactive environment', '__package__': None, ...
#          │         │    │               └ <ipykernel.zmqshell.ZMQInteractiveShell object at 0x7f94d45dfd60>
#          │         │    └ <property object at 0x7f94d73c82c0>
#          │         └ <ipykernel.zmqshell.ZMQInteractiveShell object at 0x7f94d45dfd60>
#          └ <code object <module> at 0x7f94d03ce030, file "<ipython-input-9-fef5f0ab64be>", line 15>
#   File "<ipython-input-9-fef5f0ab64be>", line 15, in <module>
#     nested(0)
#     └ <function nested at 0x7f94d03bb9d0>
# > File "<ipython-input-9-fef5f0ab64be>", line 11, in nested
#     func(5, c)
#     │       └ 0
#     └ <function func at 0x7f94d03bb8b0>
#   File "<ipython-input-9-fef5f0ab64be>", line 7, in func
#     return a / b
#            │   └ 0
#            └ 5
#
# ZeroDivisionError: division by zero
# 2020-03-29 22:39:53.647 | ERROR    | __main__:nested:13 - What?!
# Traceback (most recent call last):
#   File "/home/patrick/anaconda3/lib/python3.8/runpy.py", line 193, in _run_module_as_main
#     return _run_code(code, main_globals, None,
#            │         │     └ {'__name__': '__main__', '__doc__': 'Entry point for launching an IPython kernel.\n\nThis is separate from the ipykernel pack...
#            │         └ <code object <module> at 0x7f94d9d40030, file "/home/patrick/anaconda3/lib/python3.8/site-packages/ipykernel_launcher.py", li...
#            └ <function _run_code at 0x7f94d9cba3a0>
#   File "/home/patrick/anaconda3/lib/python3.8/runpy.py", line 86, in _run_code
#     exec(code, run_globals)
#          │     └ {'__name__': '__main__', '__doc__': 'Entry point for launching an IPython kernel.\n\nThis is separate from the ipykernel pack...
#          └ <code object <module> at 0x7f94d9d40030, file "/home/patrick/anaconda3/lib/python3.8/site-packages/ipykernel_launcher.py", li...
#   File "/home/patrick/anaconda3/lib/python3.8/site-packages/ipykernel_launcher.py", line 16, in <module>
#     app.launch_new_instance()
#     │   └ <bound method Application.launch_instance of <class 'ipykernel.kernelapp.IPKernelApp'>>
#     └ <module 'ipykernel.kernelapp' from '/home/patrick/anaconda3/lib/python3.8/site-packages/ipykernel/kernelapp.py'>
#   File "/home/patrick/anaconda3/lib/python3.8/site-packages/traitlets/config/application.py", line 664, in launch_instance
#     app.start()
#     │   └ <function IPKernelApp.start at 0x7f94d45caaf0>
#     └ <ipykernel.kernelapp.IPKernelApp object at 0x7f94d9d6c7f0>
#   File "/home/patrick/anaconda3/lib/python3.8/site-packages/ipykernel/kernelapp.py", line 583, in start
#     self.io_loop.start()
#     │    │       └ <function BaseAsyncIOLoop.start at 0x7f94d4714a60>
#     │    └ <tornado.platform.asyncio.AsyncIOMainLoop object at 0x7f94d45df2b0>
#     └ <ipykernel.kernelapp.IPKernelApp object at 0x7f94d9d6c7f0>
#   File "/home/patrick/anaconda3/lib/python3.8/site-packages/tornado/platform/asyncio.py", line 149, in start
#     self.asyncio_loop.run_forever()
#     │    │            └ <function BaseEventLoop.run_forever at 0x7f94d71ece50>
#     │    └ <_UnixSelectorEventLoop running=True closed=False debug=False>
#     └ <tornado.platform.asyncio.AsyncIOMainLoop object at 0x7f94d45df2b0>
#   File "/home/patrick/anaconda3/lib/python3.8/asyncio/base_events.py", line 567, in run_forever
#     self._run_once()
#     │    └ <function BaseEventLoop._run_once at 0x7f94d71ef9d0>
#     └ <_UnixSelectorEventLoop running=True closed=False debug=False>
#   File "/home/patrick/anaconda3/lib/python3.8/asyncio/base_events.py", line 1855, in _run_once
#     handle._run()
#     │      └ <function Handle._run at 0x7f94d72344c0>
#     └ <Handle IOLoop.add_future.<locals>.<lambda>(<Future finis...2300>, ...]))>) at /home/patrick/anaconda3/lib/python3.8/site-pac...
#   File "/home/patrick/anaconda3/lib/python3.8/asyncio/events.py", line 81, in _run
#     self._context.run(self._callback, *self._args)
#     │    │            │    │           │    └ <member '_args' of 'Handle' objects>
#     │    │            │    │           └ <Handle IOLoop.add_future.<locals>.<lambda>(<Future finis...2300>, ...]))>) at /home/patrick/anaconda3/lib/python3.8/site-pac...
#     │    │            │    └ <member '_callback' of 'Handle' objects>
#     │    │            └ <Handle IOLoop.add_future.<locals>.<lambda>(<Future finis...2300>, ...]))>) at /home/patrick/anaconda3/lib/python3.8/site-pac...
#     │    └ <member '_context' of 'Handle' objects>
#     └ <Handle IOLoop.add_future.<locals>.<lambda>(<Future finis...2300>, ...]))>) at /home/patrick/anaconda3/lib/python3.8/site-pac...
#   File "/home/patrick/anaconda3/lib/python3.8/site-packages/tornado/ioloop.py", line 690, in <lambda>
#     lambda f: self._run_callback(functools.partial(callback, future))
#            │  │    │             │         │       │         └ <Future finished result=(10, 12, <bound method...7f94d45dfdc0>>, (<zmq.eventloo...x7f94d45df580>, [<zmq.sugar.fr...x7f94d1562...
#            │  │    │             │         │       └ <function Runner.handle_yield.<locals>.inner at 0x7f94d03bbc10>
#            │  │    │             │         └ <class 'functools.partial'>
#            │  │    │             └ <module 'functools' from '/home/patrick/anaconda3/lib/python3.8/functools.py'>
#            │  │    └ <function IOLoop._run_callback at 0x7f94d481a820>
#            │  └ <tornado.platform.asyncio.AsyncIOMainLoop object at 0x7f94d45df2b0>
#            └ <Future finished result=(10, 12, <bound method...7f94d45dfdc0>>, (<zmq.eventloo...x7f94d45df580>, [<zmq.sugar.fr...x7f94d1562...
#   File "/home/patrick/anaconda3/lib/python3.8/site-packages/tornado/ioloop.py", line 743, in _run_callback
#     ret = callback()
#           └ functools.partial(<function Runner.handle_yield.<locals>.inner at 0x7f94d03bbc10>, <Future finished result=(10, 12, <bound me...
#   File "/home/patrick/anaconda3/lib/python3.8/site-packages/tornado/gen.py", line 787, in inner
#     self.run()
#     │    └ <function Runner.run at 0x7f94d4714310>
#     └ <tornado.gen.Runner object at 0x7f94d1549eb0>
#   File "/home/patrick/anaconda3/lib/python3.8/site-packages/tornado/gen.py", line 748, in run
#     yielded = self.gen.send(value)
#               │    │   │    └ (10, 12, <bound method Kernel.dispatch_shell of <ipykernel.ipkernel.IPythonKernel object at 0x7f94d45dfdc0>>, (<zmq.eventloop...
#               │    │   └ <method 'send' of 'generator' objects>
#               │    └ <generator object Kernel.process_one at 0x7f94d763c3c0>
#               └ <tornado.gen.Runner object at 0x7f94d1549eb0>
#   File "/home/patrick/anaconda3/lib/python3.8/site-packages/ipykernel/kernelbase.py", line 361, in process_one
#     yield gen.maybe_future(dispatch(*args))
#           │   │            │         └ (<zmq.eventloop.zmqstream.ZMQStream object at 0x7f94d45df580>, [<zmq.sugar.frame.Frame object at 0x7f94d15629e0>, <zmq.sugar....
#           │   │            └ <bound method Kernel.dispatch_shell of <ipykernel.ipkernel.IPythonKernel object at 0x7f94d45dfdc0>>
#           │   └ <function maybe_future at 0x7f94d4705ee0>
#           └ <module 'tornado.gen' from '/home/patrick/anaconda3/lib/python3.8/site-packages/tornado/gen.py'>
#   File "/home/patrick/anaconda3/lib/python3.8/site-packages/tornado/gen.py", line 209, in wrapper
#     yielded = next(result)
#                    └ <generator object Kernel.dispatch_shell at 0x7f94d03f6cf0>
#   File "/home/patrick/anaconda3/lib/python3.8/site-packages/ipykernel/kernelbase.py", line 268, in dispatch_shell
#     yield gen.maybe_future(handler(stream, idents, msg))
#           │   │            │       │       │       └ {'header': {'msg_id': 'd3a320bd0f53435b8eda4c2293526724', 'username': 'username', 'session': '481b4fc0ab10447f9d558f12496fe7c...
#           │   │            │       │       └ [b'481b4fc0ab10447f9d558f12496fe7cc']
#           │   │            │       └ <zmq.eventloop.zmqstream.ZMQStream object at 0x7f94d45df580>
#           │   │            └ <bound method Kernel.execute_request of <ipykernel.ipkernel.IPythonKernel object at 0x7f94d45dfdc0>>
#           │   └ <function maybe_future at 0x7f94d4705ee0>
#           └ <module 'tornado.gen' from '/home/patrick/anaconda3/lib/python3.8/site-packages/tornado/gen.py'>
#   File "/home/patrick/anaconda3/lib/python3.8/site-packages/tornado/gen.py", line 209, in wrapper
#     yielded = next(result)
#                    └ <generator object Kernel.execute_request at 0x7f94d03acf90>
#   File "/home/patrick/anaconda3/lib/python3.8/site-packages/ipykernel/kernelbase.py", line 539, in execute_request
#     self.do_execute(
#     │    └ <function IPythonKernel.do_execute at 0x7f94d45c5430>
#     └ <ipykernel.ipkernel.IPythonKernel object at 0x7f94d45dfdc0>
#   File "/home/patrick/anaconda3/lib/python3.8/site-packages/tornado/gen.py", line 209, in wrapper
#     yielded = next(result)
#                    └ <generator object IPythonKernel.do_execute at 0x7f94d03c7120>
#   File "/home/patrick/anaconda3/lib/python3.8/site-packages/ipykernel/ipkernel.py", line 300, in do_execute
#     res = shell.run_cell(code, store_history=store_history, silent=silent)
#           │     │        │                   │                     └ False
#           │     │        │                   └ True
#           │     │        └ '@logger.catch\ndef my_function(x, y, z):\n    # An error? It\'s caught anyway!\n    return 1 / (x + y + z)\n\ndef func(a, b)...
#           │     └ <function ZMQInteractiveShell.run_cell at 0x7f94d45b6b80>
#           └ <ipykernel.zmqshell.ZMQInteractiveShell object at 0x7f94d45dfd60>
#   File "/home/patrick/anaconda3/lib/python3.8/site-packages/ipykernel/zmqshell.py", line 536, in run_cell
#     return super(ZMQInteractiveShell, self).run_cell(*args, **kwargs)
#                  │                    │               │       └ {'store_history': True, 'silent': False}
#                  │                    │               └ ('@logger.catch\ndef my_function(x, y, z):\n    # An error? It\'s caught anyway!\n    return 1 / (x + y + z)\n\ndef func(a, b...
#                  │                    └ <ipykernel.zmqshell.ZMQInteractiveShell object at 0x7f94d45dfd60>
#                  └ <class 'ipykernel.zmqshell.ZMQInteractiveShell'>
#   File "/home/patrick/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py", line 2857, in run_cell
#     result = self._run_cell(
#              │    └ <function InteractiveShell._run_cell at 0x7f94d73cf4c0>
#              └ <ipykernel.zmqshell.ZMQInteractiveShell object at 0x7f94d45dfd60>
#   File "/home/patrick/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py", line 2886, in _run_cell
#     return runner(coro)
#            │      └ <coroutine object InteractiveShell.run_cell_async at 0x7f94d15489c0>
#            └ <function _pseudo_sync_runner at 0x7f94d73bbb80>
#   File "/home/patrick/anaconda3/lib/python3.8/site-packages/IPython/core/async_helpers.py", line 68, in _pseudo_sync_runner
#     coro.send(None)
#     │    └ <method 'send' of 'coroutine' objects>
#     └ <coroutine object InteractiveShell.run_cell_async at 0x7f94d15489c0>
#   File "/home/patrick/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py", line 3062, in run_cell_async
#     has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#                        │    │             │        │     └ '<ipython-input-9-fef5f0ab64be>'
#                        │    │             │        └ [<_ast.FunctionDef object at 0x7f94d046f6a0>, <_ast.FunctionDef object at 0x7f94d046f3a0>, <_ast.FunctionDef object at 0x7f94...
#                        │    │             └ <_ast.Module object at 0x7f94d046fb50>
#                        │    └ <function InteractiveShell.run_ast_nodes at 0x7f94d73cf790>
#                        └ <ipykernel.zmqshell.ZMQInteractiveShell object at 0x7f94d45dfd60>
#   File "/home/patrick/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py", line 3254, in run_ast_nodes
#     if (await self.run_code(code, result,  async_=asy)):
#               │    │        │     │               └ False
#               │    │        │     └ <ExecutionResult object at 7f94d03b2c40, execution_count=9 error_before_exec=None error_in_exec=None info=<ExecutionInfo obje...
#               │    │        └ <code object <module> at 0x7f94d03cedf0, file "<ipython-input-9-fef5f0ab64be>", line 17>
#               │    └ <function InteractiveShell.run_code at 0x7f94d73cf8b0>
#               └ <ipykernel.zmqshell.ZMQInteractiveShell object at 0x7f94d45dfd60>
#   File "/home/patrick/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py", line 3331, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#          │         │    │               │    └ {'__name__': '__main__', '__doc__': 'Automatically created module for IPython interactive environment', '__package__': None, ...
#          │         │    │               └ <ipykernel.zmqshell.ZMQInteractiveShell object at 0x7f94d45dfd60>
#          │         │    └ <property object at 0x7f94d73c82c0>
#          │         └ <ipykernel.zmqshell.ZMQInteractiveShell object at 0x7f94d45dfd60>
#          └ <code object <module> at 0x7f94d03cedf0, file "<ipython-input-9-fef5f0ab64be>", line 17>
#   File "<ipython-input-9-fef5f0ab64be>", line 17, in <module>
#     nested(0)
#     └ <function nested at 0x7f94d03bb9d0>
# > File "<ipython-input-9-fef5f0ab64be>", line 11, in nested
#     func(5, c)
#     │       └ 0
#     └ <function func at 0x7f94d03bb8b0>
#   File "<ipython-input-9-fef5f0ab64be>", line 7, in func
#     return a / b
#            │   └ 0
#            └ 5
#
# ZeroDivisionError: division by zero
# 2020-03-29T22:39:53.647639+0800 What?!
# Traceback (most recent call last):
#   File "/home/patrick/anaconda3/lib/python3.8/runpy.py", line 193, in _run_module_as_main
#     return _run_code(code, main_globals, None,
#            │         │     └ {'__name__': '__main__', '__doc__': 'Entry point for launching an IPython kernel.\n\nThis is separate from the ipykernel pack...
#            │         └ <code object <module> at 0x7f94d9d40030, file "/home/patrick/anaconda3/lib/python3.8/site-packages/ipykernel_launcher.py", li...
#            └ <function _run_code at 0x7f94d9cba3a0>
#   File "/home/patrick/anaconda3/lib/python3.8/runpy.py", line 86, in _run_code
#     exec(code, run_globals)
#          │     └ {'__name__': '__main__', '__doc__': 'Entry point for launching an IPython kernel.\n\nThis is separate from the ipykernel pack...
#          └ <code object <module> at 0x7f94d9d40030, file "/home/patrick/anaconda3/lib/python3.8/site-packages/ipykernel_launcher.py", li...
#   File "/home/patrick/anaconda3/lib/python3.8/site-packages/ipykernel_launcher.py", line 16, in <module>
#     app.launch_new_instance()
#     │   └ <bound method Application.launch_instance of <class 'ipykernel.kernelapp.IPKernelApp'>>
#     └ <module 'ipykernel.kernelapp' from '/home/patrick/anaconda3/lib/python3.8/site-packages/ipykernel/kernelapp.py'>
#   File "/home/patrick/anaconda3/lib/python3.8/site-packages/traitlets/config/application.py", line 664, in launch_instance
#     app.start()
#     │   └ <function IPKernelApp.start at 0x7f94d45caaf0>
#     └ <ipykernel.kernelapp.IPKernelApp object at 0x7f94d9d6c7f0>
#   File "/home/patrick/anaconda3/lib/python3.8/site-packages/ipykernel/kernelapp.py", line 583, in start
#     self.io_loop.start()
#     │    │       └ <function BaseAsyncIOLoop.start at 0x7f94d4714a60>
#     │    └ <tornado.platform.asyncio.AsyncIOMainLoop object at 0x7f94d45df2b0>
#     └ <ipykernel.kernelapp.IPKernelApp object at 0x7f94d9d6c7f0>
#   File "/home/patrick/anaconda3/lib/python3.8/site-packages/tornado/platform/asyncio.py", line 149, in start
#     self.asyncio_loop.run_forever()
#     │    │            └ <function BaseEventLoop.run_forever at 0x7f94d71ece50>
#     │    └ <_UnixSelectorEventLoop running=True closed=False debug=False>
#     └ <tornado.platform.asyncio.AsyncIOMainLoop object at 0x7f94d45df2b0>
#   File "/home/patrick/anaconda3/lib/python3.8/asyncio/base_events.py", line 567, in run_forever
#     self._run_once()
#     │    └ <function BaseEventLoop._run_once at 0x7f94d71ef9d0>
#     └ <_UnixSelectorEventLoop running=True closed=False debug=False>
#   File "/home/patrick/anaconda3/lib/python3.8/asyncio/base_events.py", line 1855, in _run_once
#     handle._run()
#     │      └ <function Handle._run at 0x7f94d72344c0>
#     └ <Handle IOLoop.add_future.<locals>.<lambda>(<Future finis...2300>, ...]))>) at /home/patrick/anaconda3/lib/python3.8/site-pac...
#   File "/home/patrick/anaconda3/lib/python3.8/asyncio/events.py", line 81, in _run
#     self._context.run(self._callback, *self._args)
#     │    │            │    │           │    └ <member '_args' of 'Handle' objects>
#     │    │            │    │           └ <Handle IOLoop.add_future.<locals>.<lambda>(<Future finis...2300>, ...]))>) at /home/patrick/anaconda3/lib/python3.8/site-pac...
#     │    │            │    └ <member '_callback' of 'Handle' objects>
#     │    │            └ <Handle IOLoop.add_future.<locals>.<lambda>(<Future finis...2300>, ...]))>) at /home/patrick/anaconda3/lib/python3.8/site-pac...
#     │    └ <member '_context' of 'Handle' objects>
#     └ <Handle IOLoop.add_future.<locals>.<lambda>(<Future finis...2300>, ...]))>) at /home/patrick/anaconda3/lib/python3.8/site-pac...
#   File "/home/patrick/anaconda3/lib/python3.8/site-packages/tornado/ioloop.py", line 690, in <lambda>
#     lambda f: self._run_callback(functools.partial(callback, future))
#            │  │    │             │         │       │         └ <Future finished result=(10, 12, <bound method...7f94d45dfdc0>>, (<zmq.eventloo...x7f94d45df580>, [<zmq.sugar.fr...x7f94d1562...
#            │  │    │             │         │       └ <function Runner.handle_yield.<locals>.inner at 0x7f94d03bbc10>
#            │  │    │             │         └ <class 'functools.partial'>
#            │  │    │             └ <module 'functools' from '/home/patrick/anaconda3/lib/python3.8/functools.py'>
#            │  │    └ <function IOLoop._run_callback at 0x7f94d481a820>
#            │  └ <tornado.platform.asyncio.AsyncIOMainLoop object at 0x7f94d45df2b0>
#            └ <Future finished result=(10, 12, <bound method...7f94d45dfdc0>>, (<zmq.eventloo...x7f94d45df580>, [<zmq.sugar.fr...x7f94d1562...
#   File "/home/patrick/anaconda3/lib/python3.8/site-packages/tornado/ioloop.py", line 743, in _run_callback
#     ret = callback()
#           └ functools.partial(<function Runner.handle_yield.<locals>.inner at 0x7f94d03bbc10>, <Future finished result=(10, 12, <bound me...
#   File "/home/patrick/anaconda3/lib/python3.8/site-packages/tornado/gen.py", line 787, in inner
#     self.run()
#     │    └ <function Runner.run at 0x7f94d4714310>
#     └ <tornado.gen.Runner object at 0x7f94d1549eb0>
#   File "/home/patrick/anaconda3/lib/python3.8/site-packages/tornado/gen.py", line 748, in run
#     yielded = self.gen.send(value)
#               │    │   │    └ (10, 12, <bound method Kernel.dispatch_shell of <ipykernel.ipkernel.IPythonKernel object at 0x7f94d45dfdc0>>, (<zmq.eventloop...
#               │    │   └ <method 'send' of 'generator' objects>
#               │    └ <generator object Kernel.process_one at 0x7f94d763c3c0>
#               └ <tornado.gen.Runner object at 0x7f94d1549eb0>
#   File "/home/patrick/anaconda3/lib/python3.8/site-packages/ipykernel/kernelbase.py", line 361, in process_one
#     yield gen.maybe_future(dispatch(*args))
#           │   │            │         └ (<zmq.eventloop.zmqstream.ZMQStream object at 0x7f94d45df580>, [<zmq.sugar.frame.Frame object at 0x7f94d15629e0>, <zmq.sugar....
#           │   │            └ <bound method Kernel.dispatch_shell of <ipykernel.ipkernel.IPythonKernel object at 0x7f94d45dfdc0>>
#           │   └ <function maybe_future at 0x7f94d4705ee0>
#           └ <module 'tornado.gen' from '/home/patrick/anaconda3/lib/python3.8/site-packages/tornado/gen.py'>
#   File "/home/patrick/anaconda3/lib/python3.8/site-packages/tornado/gen.py", line 209, in wrapper
#     yielded = next(result)
#                    └ <generator object Kernel.dispatch_shell at 0x7f94d03f6cf0>
#   File "/home/patrick/anaconda3/lib/python3.8/site-packages/ipykernel/kernelbase.py", line 268, in dispatch_shell
#     yield gen.maybe_future(handler(stream, idents, msg))
#           │   │            │       │       │       └ {'header': {'msg_id': 'd3a320bd0f53435b8eda4c2293526724', 'username': 'username', 'session': '481b4fc0ab10447f9d558f12496fe7c...
#           │   │            │       │       └ [b'481b4fc0ab10447f9d558f12496fe7cc']
#           │   │            │       └ <zmq.eventloop.zmqstream.ZMQStream object at 0x7f94d45df580>
#           │   │            └ <bound method Kernel.execute_request of <ipykernel.ipkernel.IPythonKernel object at 0x7f94d45dfdc0>>
#           │   └ <function maybe_future at 0x7f94d4705ee0>
#           └ <module 'tornado.gen' from '/home/patrick/anaconda3/lib/python3.8/site-packages/tornado/gen.py'>
#   File "/home/patrick/anaconda3/lib/python3.8/site-packages/tornado/gen.py", line 209, in wrapper
#     yielded = next(result)
#                    └ <generator object Kernel.execute_request at 0x7f94d03acf90>
#   File "/home/patrick/anaconda3/lib/python3.8/site-packages/ipykernel/kernelbase.py", line 539, in execute_request
#     self.do_execute(
#     │    └ <function IPythonKernel.do_execute at 0x7f94d45c5430>
#     └ <ipykernel.ipkernel.IPythonKernel object at 0x7f94d45dfdc0>
#   File "/home/patrick/anaconda3/lib/python3.8/site-packages/tornado/gen.py", line 209, in wrapper
#     yielded = next(result)
#                    └ <generator object IPythonKernel.do_execute at 0x7f94d03c7120>
#   File "/home/patrick/anaconda3/lib/python3.8/site-packages/ipykernel/ipkernel.py", line 300, in do_execute
#     res = shell.run_cell(code, store_history=store_history, silent=silent)
#           │     │        │                   │                     └ False
#           │     │        │                   └ True
#           │     │        └ '@logger.catch\ndef my_function(x, y, z):\n    # An error? It\'s caught anyway!\n    return 1 / (x + y + z)\n\ndef func(a, b)...
#           │     └ <function ZMQInteractiveShell.run_cell at 0x7f94d45b6b80>
#           └ <ipykernel.zmqshell.ZMQInteractiveShell object at 0x7f94d45dfd60>
#   File "/home/patrick/anaconda3/lib/python3.8/site-packages/ipykernel/zmqshell.py", line 536, in run_cell
#     return super(ZMQInteractiveShell, self).run_cell(*args, **kwargs)
#                  │                    │               │       └ {'store_history': True, 'silent': False}
#                  │                    │               └ ('@logger.catch\ndef my_function(x, y, z):\n    # An error? It\'s caught anyway!\n    return 1 / (x + y + z)\n\ndef func(a, b...
#                  │                    └ <ipykernel.zmqshell.ZMQInteractiveShell object at 0x7f94d45dfd60>
#                  └ <class 'ipykernel.zmqshell.ZMQInteractiveShell'>
#   File "/home/patrick/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py", line 2857, in run_cell
#     result = self._run_cell(
#              │    └ <function InteractiveShell._run_cell at 0x7f94d73cf4c0>
#              └ <ipykernel.zmqshell.ZMQInteractiveShell object at 0x7f94d45dfd60>
#   File "/home/patrick/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py", line 2886, in _run_cell
#     return runner(coro)
#            │      └ <coroutine object InteractiveShell.run_cell_async at 0x7f94d15489c0>
#            └ <function _pseudo_sync_runner at 0x7f94d73bbb80>
#   File "/home/patrick/anaconda3/lib/python3.8/site-packages/IPython/core/async_helpers.py", line 68, in _pseudo_sync_runner
#     coro.send(None)
#     │    └ <method 'send' of 'coroutine' objects>
#     └ <coroutine object InteractiveShell.run_cell_async at 0x7f94d15489c0>
#   File "/home/patrick/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py", line 3062, in run_cell_async
#     has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#                        │    │             │        │     └ '<ipython-input-9-fef5f0ab64be>'
#                        │    │             │        └ [<_ast.FunctionDef object at 0x7f94d046f6a0>, <_ast.FunctionDef object at 0x7f94d046f3a0>, <_ast.FunctionDef object at 0x7f94...
#                        │    │             └ <_ast.Module object at 0x7f94d046fb50>
#                        │    └ <function InteractiveShell.run_ast_nodes at 0x7f94d73cf790>
#                        └ <ipykernel.zmqshell.ZMQInteractiveShell object at 0x7f94d45dfd60>
#   File "/home/patrick/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py", line 3254, in run_ast_nodes
#     if (await self.run_code(code, result,  async_=asy)):
#               │    │        │     │               └ False
#               │    │        │     └ <ExecutionResult object at 7f94d03b2c40, execution_count=9 error_before_exec=None error_in_exec=None info=<ExecutionInfo obje...
#               │    │        └ <code object <module> at 0x7f94d03cedf0, file "<ipython-input-9-fef5f0ab64be>", line 17>
#               │    └ <function InteractiveShell.run_code at 0x7f94d73cf8b0>
#               └ <ipykernel.zmqshell.ZMQInteractiveShell object at 0x7f94d45dfd60>
#   File "/home/patrick/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py", line 3331, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#          │         │    │               │    └ {'__name__': '__main__', '__doc__': 'Automatically created module for IPython interactive environment', '__package__': None, ...
#          │         │    │               └ <ipykernel.zmqshell.ZMQInteractiveShell object at 0x7f94d45dfd60>
#          │         │    └ <property object at 0x7f94d73c82c0>
#          │         └ <ipykernel.zmqshell.ZMQInteractiveShell object at 0x7f94d45dfd60>
#          └ <code object <module> at 0x7f94d03cedf0, file "<ipython-input-9-fef5f0ab64be>", line 17>
#   File "<ipython-input-9-fef5f0ab64be>", line 17, in <module>
#     nested(0)
#     └ <function nested at 0x7f94d03bb9d0>
# > File "<ipython-input-9-fef5f0ab64be>", line 11, in nested
#     func(5, c)
#     │       └ 0
#     └ <function func at 0x7f94d03bb8b0>
#   File "<ipython-input-9-fef5f0ab64be>", line 7, in func
#     return a / b
#            │   └ 0
#            └ 5
#
# ZeroDivisionError: division by zero

# %% [markdown]
# ## Asynchronous,Thread-safe,multiprocess-safe, scripts and libraries

# %%
logger.add("somefile.log", enqueue=True)
logger.add(sys.stdout, colorize=True, format="<green>{time}</green> <level>{message}</level>")
logger.info("log color testing")
# For scripts
config = {
    "handlers": [
        {"sink": sys.stdout, "format": "{time} - {message}"},
        {"sink": "file.log", "serialize": True},
    ],
    "extra": {"user": "someone"}
}
logger.configure(**config)

# For libraries
logger.disable("my_library")
logger.info("No matter added sinks, this message is not displayed")
logger.enable("my_library")
logger.info("This message however is propagated to the sinks")
# Out:
# 2020-03-29 22:42:03.003 | INFO     | __main__:<module>:3 - log color testing
# 2020-03-29T22:42:03.003642+0800 log color testing
# 2020-03-29T22:42:03.003642+0800 log color testing
# 2020-03-29T22:42:03.027126+0800 - No matter added sinks, this message is not displayed
# 2020-03-29T22:42:03.029172+0800 - This message however is propagated to the sinks

# %%
## Integrate with notifier 

* [notifiers](https://github.com/notifiers/notifiers)

# %%
import notifiers

params = {
    "username": "you@gmail.com",
    "password": "abc123",
    "to": "dest@gmail.com"
}

# Send a single notification
notifier = notifiers.get_notifier("gmail")
notifier.notify(message="The application is running!", **params)

# Be alerted on each error message
from notifiers.logging import NotificationHandler

handler = NotificationHandler("gmail", defaults=params)
logger.add(handler, level="ERROR")
logger.info("some error happened")
# Out:
# 16

# %%
## Define System Environement and Parse the log

# %%
# Linux / OSX
export LOGURU_FORMAT="{time} | <lvl>{message}</lvl>"

# Windows
setx LOGURU_DEBUG_COLOR "<green>"
pattern = r"(?P<time>.*) - (?P<level>[0-9]+) - (?P<message>.*)"  # Regex with named groups
caster_dict = dict(time=dateutil.parser.parse, level=int)        # Transform matching groups

for groups in logger.parse("file.log", pattern, cast=caster_dict):
    print("Parsed:", groups)
    # {"level": 30, "message": "Log example", "time": datetime(2018, 12, 09, 11, 23, 55)}
